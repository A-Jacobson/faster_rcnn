# %%
# %matplotlib inline
import torch
from torchvision import transforms
from models import FasterRCNN, BaseCNN, RegionProposalNetwork, Detector
from datasets import PascalVOC
from visualize import plot_with_targets
from utils import bbox_transform_inv
from config import DATA_PATH, SCALE, MEAN, STD

# %%
transform = transforms.Compose([transforms.Scale(SCALE),
                                transforms.ToTensor(),
                                transforms.Normalize(MEAN, STD)])

# %%
def recover_imagenet(tensor):
    mean, std = [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]
    mu = torch.Tensor(mean).view(-1, 1, 1)
    sigma = torch.Tensor(std).view(-1, 1, 1)
    return tensor_to_img((tensor * sigma + mu).clamp(0, 1))

def tensor_to_img(tensor):
    return transforms.ToPILImage()(tensor)

# %%
data = PascalVOC(DATA_PATH, transform)
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!

# %%
img, target = data[2]

# %%
5 % 5 == 0
# Out:
# True

# %%
data.classes
# Out:
# {0: 'background',
#  1: 'aeroplane',
#  2: 'bicycle',
#  3: 'bird',
#  4: 'boat',
#  5: 'bottle',
#  6: 'bus',
#  7: 'car',
#  8: 'cat',
#  9: 'chair',
#  10: 'cow',
#  11: 'diningtable',
#  12: 'dog',
#  13: 'horse',
#  14: 'motorbike',
#  15: 'person',
#  16: 'pottedtable',
#  17: 'sheep',
#  18: 'sofa',
#  19: 'train',
#  20: 'tvmonitor'}

# %%
plot_with_targets(recover_imagenet(img), target, data.classes)

# %%
basecnn = BaseCNN()
rpn = RegionProposalNetwork()
classifier = Classifier()

# %%
frcnn = FasterRCNN(basecnn, rpn, classifier)

# %%
checkpoint = torch.load('weights/EXP2/5_5.9726')

# %%
frcnn.load_state_dict(checkpoint['model_state'])

# %%
from torch.autograd import Variable

# %%
rpn_cls_probs, rpn_bbox_deltas, pred_label, pred_bbox_deltas = frcnn(Variable(img.unsqueeze(0)))

# %%
frcnn.rpn.all_anchor_boxes
# Out:
# array([[ -83.,  -39.,  100.,   56.],
#        [-175.,  -87.,  192.,  104.],
#        [-359., -183.,  376.,  200.],
#        ...,
#        [ 253.,  369.,  340.,  544.],
#        [ 209.,  281.,  384.,  632.],
#        [ 121.,  105.,  472.,  808.]])

# %%
rpn_deltas = rpn_bbox_deltas.data.numpy()
val, idx = rpn_cls_probs.max(dim=1)

# %%
idx == 1
# Out:
# Variable containing:
#  0
#  0
#  0
# ⋮
#  0
#  0
#  0
# [torch.ByteTensor of size 4959]

# %%
rpn_labels, bbox_targets, batch_indices  = frcnn.get_rpn_targets(target)

# %%
from torchvision.models import resnet34

# %%
resnet = resnet34()

# %%
from torch import nn

# %%
features = nn.Sequential(*list(resnet.children())[:-3])

# %%
features[-1].parameters()
# Out:
# <generator object Module.parameters at 0x7f6abf10fbf8>

# %%
features
# Out:
# Sequential (
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (2): ReLU (inplace)
#   (3): MaxPool2d (size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=(1, 1))
#   (4): Sequential (
#     (0): BasicBlock (
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#     )
#     (1): BasicBlock (
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#       (relu): ReLU (inplace)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
